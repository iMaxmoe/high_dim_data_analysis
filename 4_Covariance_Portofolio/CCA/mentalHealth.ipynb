# %%
import numpy as np
import pandas as pd

df = pd.read_csv("Mental_Health_survey.csv")
df.head()
# Out:
#        Timestamp  Age  Gender         Country state self_employed  \
# 0  8/27/14 11:29   37  Female   United States    IL           NaN
# 1  8/27/14 11:29   44       M   United States    IN           NaN
# 2  8/27/14 11:29   32    Male          Canada   NaN           NaN
# 3  8/27/14 11:29   31    Male  United Kingdom   NaN           NaN
# 4  8/27/14 11:30   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees   ...     \
# 0             No       Yes          Often          25-Jun   ...
# 1             No        No         Rarely  More than 1000   ...
# 2             No        No         Rarely          25-Jun   ...
# 3            Yes       Yes          Often          26-100   ...
# 4             No        No          Never         100-500   ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# ...

# %%
from sklearn.preprocessing import LabelEncoder

enc = LabelEncoder()
policies_list = ["benefits", "care_options", "wellness_program", "seek_help", "anonymity", "leave"]
policies_on_MH = df[policies_list]
for i in range(5):
    y = policies_on_MH.iloc[:,i]
    y = enc.fit_transform(y) - 1
    policies_on_MH.iloc[:,i] = y
    
y = policies_on_MH.loc[:,"leave"]
y = enc.fit_transform(y) - 2
policies_on_MH.loc[:,"leave"] = y
# Out:
# D:\Tool\Anaconda\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# D:\Tool\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
openness_list = ["mental_health_consequence", "phys_health_consequence", "coworkers",
                        "supervisor", "mental_health_interview", "phys_health_interview",
                        "mental_vs_physical", "obs_consequence"]
openness_of_MH = df[openness_list]
for i in range(7):
    y = openness_of_MH.iloc[:,i]
    y = enc.fit_transform(y) - 1
    openness_of_MH.iloc[:,i] = y
    
y = openness_of_MH.iloc[:,-1]
y = enc.fit_transform(y)
openness_of_MH.iloc[:,-1] = y
# Out:
# D:\Tool\Anaconda\lib\site-packages\pandas\core\indexing.py:630: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# D:\Tool\Anaconda\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
from sklearn.cross_decomposition import CCA

#policies_on_MH = policies_on_MH.reset_index()
cca = CCA()
cca.fit_transform(policies_on_MH,openness_of_MH)
# Out:
# (array([[ 1.4407789 ,  0.81002327],
#         [-1.70530801, -1.37892191],
#         [-0.71329041, -0.23561314],
#         ...,
#         [-0.40860645,  0.84121926],
#         [-0.9022631 ,  0.94023372],
#         [ 0.17309858,  1.75270155]]), array([[ 1.62090825,  0.1299895 ],
#         [-1.68811405,  0.71480792],
#         [ 0.93477967,  0.0457168 ],
#         ...,
#         [-0.05405424, -0.21423209],
#         [-0.17950998,  0.20023419],
#         [-1.57039866, -0.21685423]]))
